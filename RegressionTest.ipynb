# %%
import numpy as np # linear algebra
from matplotlib import pyplot as plt
#We need these in this file:
import sys
sys.path.append('cropping')
sys.path.append('scripts')
import load_read_name_extractor as lrne
import SVM_classifier_general as svm_general

#Taget fra længere nede i koden:
import torch
from torchvision import transforms
from PIL import Image
import random
import itertools
import torch
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import DeepFunctions as df
from random import shuffle
from torch.utils.data import Dataset, DataLoader, random_split
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.model_selection import train_test_split
from torchvision import transforms
from IPython.display import display
import os
import json

# %%
img_list, names = lrne.load_name_and_img("cropped_mean/*jpeg")

# %%
print(len(img_list))
print(len(names))
# Out:
# 4915
# 4915

# %%
# pick a random index
random_index = random.randint(0, len(img_list)-1)

# get the corresponding image and name
random_img = img_list[random_index]
random_name = names[random_index]

# show the image and print the name
plt.imshow(random_img)
plt.show()
print(random_name)

# show the first image and print the name
plt.imshow(img_list[0])
plt.show()
print(names[0])
# Out:
# cropped_mean/194_200603_Min.jpeg
# cropped_mean/124_200528_Min.jpeg

# %%
date_ = False
bin_size = 10
n_bins = int(np.floor(100/bin_size))
labels = svm_general.load_labels(bin_size, date_)
print(labels[0])
print(len(labels))

#convert names into [flight_folder, ROI]
names_labels = lrne.it_name_extract_labels_from_img_jpeg(names)
print(names_labels[0])
lodging_score = [[] for _ in range(4915)]

#match labels with feature names
lodging_score = svm_general.match_pic_label_to_names_new(lodging_score, labels, names_labels, date_)
# Out:
# ['262' '5' '180529_Bj' '0']
# 4936
# ['124', '200528_Min']

# %%
lodging_score_int = [[int(char) for char in sublist] for sublist in lodging_score]
flattened_list = list(itertools.chain.from_iterable(lodging_score_int))
#print(flattened_list)
lodging_score = flattened_list
#print(max(lodging_score_int))
count_9 = lodging_score.count(9)
print(count_9)

print(np.shape(img_list))
print(np.shape(flattened_list))
# Out:
# 1
# (4915, 144, 496, 3)
# (4915,)

# %% [markdown]
# # Remember to change the cuda:0 value. Should match a free GPU on the cluster or if using local probably just cuda:0.

# %%
# Call the function to list GPU names
df.list_gpu_names()
#R
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# Number of available GPUs: 4
# GPU 0: NVIDIA TITAN X (Pascal)
# GPU 1: NVIDIA TITAN X (Pascal)
# GPU 2: NVIDIA TITAN X (Pascal)
# GPU 3: NVIDIA TITAN X (Pascal)
# cuda:2

# %%
class ImageDataset(Dataset):
    def __init__(self, img_list, lodging_score, transform=None):
        self.img_list = img_list
        self.lodging_score = lodging_score
        self.transform = transform
        self.mean = 0
        
    def __len__(self):
        return len(self.img_list)
    
    def __getitem__(self, idx):
        img = self.img_list[idx]
        score = self.lodging_score[idx]

        # Convert image to tensor and apply transformations
        if self.transform:
            img = self.transform(img)

        return img, score
    def get_labels(self):
        return self.lodging_score

transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((144, 496)),
    #transforms.Grayscale(),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485], std=[0.229]),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

])

# %%
# Combine img_list and lodging_score
combined_data = list(zip(img_list, lodging_score))

# Shuffle the combined data
shuffle(combined_data)

# Unzip the shuffled data
img_list, lodging_score = zip(*combined_data)
dataSet = ImageDataset(img_list, lodging_score, transform=transform)
print(dataSet[0][1])
count_0 = lodging_score.count(0)
print(count_0)
# Out:
# 1
# 2314

# %%
dataSet = df.filter_data(dataSet)
print(len(dataSet[0]))
print(len(dataSet))
print(dataSet[0][0].shape)
# Out:
# 2
# 3100
# torch.Size([3, 144, 496])

# %%
# Usage example
augmented_dataSet = df.augment_data(dataSet)
dataSet = augmented_dataSet

# %%
print(len(dataSet[0]))
print(len(dataSet))
#print(type(dataSet[0][0]))


# Assuming img is a PIL.Image.Image object
display(dataSet[0][0].shape)
# Out:
# 2
# 12400
# torch.Size([3, 144, 496])

# %%
#Split into train and validation set
random_seed = 10587
testValSize = (2/5) * len(dataSet)
trainDataset, testvalDataset = train_test_split(dataSet, test_size=int(testValSize), random_state=random_seed, shuffle=True)
validationSize = (1/2) * len(testvalDataset)
testDataset, valDataset = train_test_split(testvalDataset, test_size=int(validationSize), random_state=random_seed, shuffle=True)

#Create dataloaders
batchSize = 64
trainDataloader = DataLoader(trainDataset, batch_size=batchSize, shuffle=True)
testDataloader = DataLoader(testDataset, batch_size=batchSize, shuffle=True)
valDataloader = DataLoader(valDataset, batch_size=batchSize, shuffle=True)

#Print sizes
print(len(trainDataset), len(testDataset), len(valDataset))
print(dataSet[0][0].shape)
# Out:
# 7440 2480 2480
# torch.Size([3, 144, 496])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#We have ignored class 9 since there were only 1 image with that class. Therfore we have 9 classes.
num_classes = 9
channels = dataSet[0][0].shape[0]
height = dataSet[0][0].shape[1]
width = dataSet[0][0].shape[2]
print(channels)
print(height)
print(width)
# Out:
# 3
# 144
# 496

# %%
kernel_size = 3
kernel_size1 = 3
padding = 0
# define network
conv1toconv2 = 64
conv2toconv3 = 128
conv3toconv4 = 256
conv4toconv5 = 128
conv5toconv6 = 128
conv6tolin1 = 128
class NeuralNetwork(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(NeuralNetwork, self).__init__()

        self.conv1 = nn.Conv2d(3, conv1toconv2, kernel_size, padding=padding)
        self.bn1 = nn.BatchNorm2d(conv1toconv2)

        self.conv2 = nn.Conv2d(conv1toconv2, conv2toconv3, kernel_size1, padding=padding)
        self.bn2 = nn.BatchNorm2d(conv2toconv3)

        self.conv3 = nn.Conv2d(conv2toconv3, conv3toconv4, kernel_size1, padding=padding)
        self.bn3 = nn.BatchNorm2d(conv3toconv4)

        self.conv4 = nn.Conv2d(conv3toconv4, conv4toconv5, kernel_size1, padding=padding)
        self.bn4 = nn.BatchNorm2d(conv4toconv5)

        self.conv5 = nn.Conv2d(conv4toconv5, conv5toconv6, kernel_size1, padding=padding)
        self.bn5 = nn.BatchNorm2d(conv5toconv6)

        self.conv6 = nn.Conv2d(conv5toconv6, conv6tolin1, kernel_size, padding=padding)
        self.bn6 = nn.BatchNorm2d(conv6tolin1)

        self.pool = nn.AvgPool2d(2, 2)
        self.flatten = nn.Flatten()
        self.FC1 = nn.Linear(2 * 13 * conv6tolin1, 256)
        self.bn7 = nn.BatchNorm1d(256)

        self.FC2 = nn.Linear(256, 512)
        self.bn8 = nn.BatchNorm1d(512)

        self.FC3 = nn.Linear(512, 256)
        self.bn9 = nn.BatchNorm1d(256)

        self.FC4 = nn.Linear(256, 1)  # Change output size to 1 for regression

        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv4(x)
        x = self.bn4(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv5(x)
        x = self.bn5(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.flatten(x)
        x = self.FC1(x)
        x = self.bn7(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.FC2(x)
        x = self.bn8(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.FC3(x)
        x = self.bn9(x)
        x = F.relu(x)
        x = self.FC4(x)

        return x

# %%
import get_lodging_scores as g
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
net = NeuralNetwork()
net.to(device)
print(net)

# Define the loss function for regression
criterion = nn.MSELoss().to(device)  # Mean Squared Error Loss for regression

learning_rate = 0.001
# Define the optimizer
optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# Set the weight decay parameter for L2 regularization
weight_decay = 1e-8  # You can adjust this value based on your needs
# Use the Adam optimizer with L2 regularization
optimizer = optim.Adam(net.parameters(), lr=learning_rate)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, verbose=True)

# Set the number of epochs
num_epochs = 50
totalAcc = 0

trainAccList = []
valAccList = []
trainLossList = []
valLossList = []
rmse_list = []
val_rmse_list = []

# Training loop
for epoch in range(num_epochs):
    running_loss = 0.0
    totalAcc = 0.0
    val_running_loss = 0.0
    val_totalAcc = 0.0
    rmse = 0.0
    val_rmse = 0.0

    for i, data in enumerate(trainDataloader, 0):
        net.train()
        # Get the inputs and labels
        inputs, labels = data

        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = net(inputs)
        
        t_out = []
        for out in outputs.squeeze().tolist():
            t_out.append(g.create_bin(bin_size, out))
            
        totalAcc += torch.eq(torch.tensor(t_out).to(device), labels).sum()  # Assuming labels are continuous values for regression
        rmse += ((outputs - labels)**2).mean().item()
        loss = criterion(outputs.squeeze(), labels.float())  # Ensure labels are treated as float for regression

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Print statistics
        running_loss += loss.item()

    for i, data in enumerate(valDataloader, 0):
        net.eval()
        # Get the inputs and labels
        inputs, labels = data
        data=None
        inputs, labels = inputs.to(device), labels.to(device)

        # Forward pass
        outputs = net(inputs)
        t_out = []
        for out in outputs.squeeze().tolist():
            t_out.append(g.create_bin(bin_size, out))
            
        val_totalAcc += torch.eq(torch.tensor(t_out).to(device), labels).sum()  # Assuming labels are continuous values for regression
        val_rmse += ((outputs - labels)**2).mean().item()
        loss = criterion(outputs.squeeze(), labels.float())

        # Print statistics
        val_running_loss += loss.item()

    scheduler.step(val_running_loss)
    
    trainAccList.append(totalAcc / len(trainDataset))
    valAccList.append(val_totalAcc / len(valDataset))
    trainLossList.append(running_loss / len(trainDataloader))
    valLossList.append(val_running_loss / len(valDataloader))
    rmse_list.append(rmse / len(trainDataloader))
    val_rmse_list.append(val_rmse / len(valDataloader))
    
    print('[%d] train loss: %.3f train acc: %.3f train rmse: %.3f val loss: %.3f val acc: %.3f val rmse: %.3f '
          % (epoch + 1, trainLossList[epoch], trainAccList[epoch], rmse_list[epoch], valLossList[epoch], valAccList[epoch], val_rmse_list[epoch]))

    running_loss = 0.0
    totalAcc = 0.0
    val_running_loss = 0.0
    val_totalAcc = 0.0
    rmse = 0.0
    val_rmse = 0.0
    current_learning_rate = optimizer.param_groups[0]['lr']
    
    # Break if val_loss is below a certain threshold or learning rate is too small
    if valLossList[epoch] < 0.01 or current_learning_rate < 1e-6:
        print("Validation loss reached below 0.01 or learning rate below 1e-6. Stopping training.")
        break

print('Finished training')
# Out:
# NeuralNetwork(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#   (bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (FC1): Linear(in_features=3328, out_features=256, bias=True)
#   (bn7): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (FC2): Linear(in_features=256, out_features=512, bias=True)
#   (bn8): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (FC3): Linear(in_features=512, out_features=256, bias=True)
#   (bn9): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (FC4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# [1] train loss: 4.530 train acc: 0.163 train rmse: 11.049 val loss: 2.600 val acc: 0.152 val rmse: 10.030
# [2] train loss: 3.239 train acc: 0.163 train rmse: 10.251 val loss: 2.990 val acc: 0.152 val rmse: 11.872
# [3] train loss: 2.659 train acc: 0.163 train rmse: 10.813 val loss: 3.776 val acc: 0.152 val rmse: 13.711
# [4] train loss: 2.484 train acc: 0.163 train rmse: 10.846 val loss: 2.121 val acc: 0.152 val rmse: 10.251
# [5] train loss: 2.382 train acc: 0.163 train rmse: 10.910 val loss: 3.898 val acc: 0.152 val rmse: 15.006
# [6] train loss: 2.187 train acc: 0.163 train rmse: 11.125 val loss: 1.973 val acc: 0.152 val rmse: 9.361
# [7] train loss: 1.982 train acc: 0.163 train rmse: 11.254 val loss: 1.623 val acc: 0.152 val rmse: 10.187
# [8] train loss: 1.978 train acc: 0.163 train rmse: 11.280 val loss: 1.487 val acc: 0.152 val rmse: 11.142
# [9] train loss: 1.803 train acc: 0.163 train rmse: 11.417 val loss: 2.500 val acc: 0.152 val rmse: 13.816
# [10] train loss: 1.747 train acc: 0.163 train rmse: 11.549 val loss: 1.639 val acc: 0.152 val rmse: 10.420
# [11] train loss: 1.761 train acc: 0.163 train rmse: 11.502 val loss: 1.371 val acc: 0.152 val rmse: 10.805
# [12] train loss: 1.678 train acc: 0.163 train rmse: 11.548 val loss: 1.506 val acc: 0.152 val rmse: 10.048
# [13] train loss: 1.608 train acc: 0.163 train rmse: 11.564 val loss: 1.470 val acc: 0.152 val rmse: 11.546
# [14] train loss: 1.530 train acc: 0.163 train rmse: 11.686 val loss: 1.363 val acc: 0.152 val rmse: 10.917
# [15] train loss: 1.482 train acc: 0.163 train rmse: 11.707 val loss: 1.244 val acc: 0.152 val rmse: 10.969
# [16] train loss: 1.489 train acc: 0.163 train rmse: 11.730 val loss: 1.195 val acc: 0.152 val rmse: 10.979
# [17] train loss: 1.452 train acc: 0.163 train rmse: 11.721 val loss: 1.190 val acc: 0.152 val rmse: 10.782
# [18] train loss: 1.445 train acc: 0.163 train rmse: 11.731 val loss: 1.253 val acc: 0.152 val rmse: 11.716
# [19] train loss: 1.315 train acc: 0.163 train rmse: 11.900 val loss: 1.411 val acc: 0.152 val rmse: 12.722
# [20] train loss: 1.409 train acc: 0.163 train rmse: 11.829 val loss: 1.316 val acc: 0.152 val rmse: 10.623
# [21] train loss: 1.383 train acc: 0.163 train rmse: 11.784 val loss: 1.246 val acc: 0.152 val rmse: 11.043
# [22] train loss: 1.375 train acc: 0.163 train rmse: 11.818 val loss: 1.174 val acc: 0.152 val rmse: 11.217
# [23] train loss: 1.332 train acc: 0.163 train rmse: 11.928 val loss: 1.184 val acc: 0.152 val rmse: 10.805
# [24] train loss: 1.320 train acc: 0.163 train rmse: 11.820 val loss: 1.179 val acc: 0.152 val rmse: 11.615
# [25] train loss: 1.319 train acc: 0.163 train rmse: 11.845 val loss: 1.214 val acc: 0.152 val rmse: 11.072
# [26] train loss: 1.264 train acc: 0.163 train rmse: 11.895 val loss: 1.108 val acc: 0.152 val rmse: 11.401
# [27] train loss: 1.202 train acc: 0.163 train rmse: 11.993 val loss: 1.264 val acc: 0.152 val rmse: 10.662
# [28] train loss: 1.191 train acc: 0.163 train rmse: 11.955 val loss: 1.105 val acc: 0.152 val rmse: 11.281
# [29] train loss: 1.144 train acc: 0.163 train rmse: 12.035 val loss: 1.079 val acc: 0.152 val rmse: 11.258
# [30] train loss: 1.117 train acc: 0.163 train rmse: 12.076 val loss: 1.101 val acc: 0.152 val rmse: 11.458
# [31] train loss: 1.131 train acc: 0.163 train rmse: 12.004 val loss: 1.184 val acc: 0.152 val rmse: 11.646
# [32] train loss: 1.128 train acc: 0.163 train rmse: 12.060 val loss: 1.282 val acc: 0.152 val rmse: 10.400
# [33] train loss: 1.114 train acc: 0.163 train rmse: 11.993 val loss: 1.149 val acc: 0.152 val rmse: 11.409
# [34] train loss: 1.039 train acc: 0.163 train rmse: 12.147 val loss: 1.078 val acc: 0.152 val rmse: 11.301
# [35] train loss: 1.069 train acc: 0.163 train rmse: 12.102 val loss: 1.119 val acc: 0.152 val rmse: 11.494
# [36] train loss: 1.001 train acc: 0.163 train rmse: 12.119 val loss: 1.054 val acc: 0.152 val rmse: 11.539
# [37] train loss: 0.990 train acc: 0.163 train rmse: 12.211 val loss: 1.011 val acc: 0.152 val rmse: 11.296
# [38] train loss: 0.955 train acc: 0.163 train rmse: 12.179 val loss: 1.095 val acc: 0.152 val rmse: 11.036
# [39] train loss: 0.986 train acc: 0.163 train rmse: 12.180 val loss: 1.140 val acc: 0.152 val rmse: 11.325
# [40] train loss: 0.925 train acc: 0.163 train rmse: 12.191 val loss: 1.005 val acc: 0.152 val rmse: 11.324
# [41] train loss: 0.876 train acc: 0.163 train rmse: 12.228 val loss: 1.160 val acc: 0.152 val rmse: 11.743
# [42] train loss: 0.901 train acc: 0.163 train rmse: 12.197 val loss: 1.031 val acc: 0.152 val rmse: 11.878
# [43] train loss: 0.823 train acc: 0.163 train rmse: 12.342 val loss: 1.116 val acc: 0.152 val rmse: 11.474
# [44] train loss: 0.790 train acc: 0.163 train rmse: 12.301 val loss: 1.135 val acc: 0.152 val rmse: 12.034
# [45] train loss: 0.762 train acc: 0.163 train rmse: 12.404 val loss: 1.019 val acc: 0.152 val rmse: 11.634
# Epoch 00046: reducing learning rate of group 0 to 1.0000e-04.
# [46] train loss: 0.801 train acc: 0.163 train rmse: 12.308 val loss: 1.068 val acc: 0.152 val rmse: 12.520
# [47] train loss: 0.638 train acc: 0.163 train rmse: 12.432 val loss: 0.930 val acc: 0.152 val rmse: 11.590
# [48] train loss: 0.640 train acc: 0.163 train rmse: 12.469 val loss: 0.933 val acc: 0.152 val rmse: 11.819
# [49] train loss: 0.588 train acc: 0.163 train rmse: 12.392 val loss: 0.927 val acc: 0.152 val rmse: 11.802
# [50] train loss: 0.573 train acc: 0.163 train rmse: 12.503 val loss: 0.925 val acc: 0.152 val rmse: 11.455
# Finished training

# %%
df.plot_loss_and_accuracy(df.transfer_to_cpu(trainLossList), df.transfer_to_cpu(rmse_list), df.transfer_to_cpu(valLossList), df.transfer_to_cpu(val_rmse_list))

# %%
cm1, acc1 = df.create_confusion_matrix(trainDataloader, net, device=device)
title1 = 'Confusion matrix for training set'

cm2, acc2 = df.create_confusion_matrix(valDataloader, net, device=device)
title2 = 'Confusion matrix for validation set'

cm3, acc3 = df.create_confusion_matrix(testDataloader, net, device=device)
title3 = 'Confusion matrix for test set'

df.plot_3_confusion_matrices(cm1, cm2, cm3, acc1, acc2, acc3, num_classes, title1, title2, title3)

# %%
# Example usage:
# Assuming you have your confusion matrices and accuracies
layer_sizes = [conv1toconv2, conv2toconv3, conv3toconv4, conv4toconv5, conv5toconv6, conv6tolin1]

# Save the results to a file
df.save_results_to_file(layer_sizes, cm1, acc1, cm2, acc2, cm3, acc3)
